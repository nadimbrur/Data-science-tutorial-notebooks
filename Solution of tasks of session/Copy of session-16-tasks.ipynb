# %% [markdown]
# ###`Q-1:` Write a program to create an empty series.

# %%
# code here
import pandas as pd
a=pd.Series()
a
# Out:
# Series([], dtype: object)

# %% [markdown]
# ###`Q-2:` Write a Pandas program to add, subtract, multiple and divide two Pandas Series.

# %%
# code here
a=pd.Series([1,2,3,4,5])
b=pd.Series([5,4,3,2,1])
a-b
# Out:
# 0   -4
# 1   -2
# 2    0
# 3    2
# 4    4
# dtype: int64

# %% [markdown]
# ###`Q-3` Write a Pandas program to compare the elements of the two Pandas Series.
# Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 10]

# %%
# code here
import pandas as pd
a=pd.Series([2, 4, 6, 8, 10])
b=pd.Series([1, 3, 5, 7, 10])
a==b
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# ###`Q-5.`Write a function to change the data type of given a column or a Series. Function takes series and data type as input, returns the converted series.
# ```
# series = pd.Series([1,2,'Python', 2.0, True, 100])
# change to float type data
# ```
# Note: Read about pd.to_numeric()

# %%
# code here
series = pd.Series([1,2,'Python', 2.0, True, 100])
pd.to_numeric(series, errors='ignore')
# Out:
# 0         1
# 1         2
# 2    Python
# 3       2.0
# 4      True
# 5       100
# dtype: object

# %% [markdown]
# Download data - https://drive.google.com/file/d/1LRhXwbEodeWXtzPhJCX0X9Lf_BECzvqb/view?usp=share_link
# All Batsman runs series in IPL 2008 to 2022.
#
# Below questions are based on this data.

# %% [markdown]
# ###`Q-6` Find top 10 most run getter from the series.

# %%
# code here

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
run=pd.read_csv('/content/drive/MyDrive/Learn_DS_dataset/batsman_runs_series.csv',index_col='batter')
run=run.squeeze()

# %%
run.sort_values(ascending=False).head(10)
# Out:
# batter
# V Kohli           6634
# S Dhawan          6244
# DA Warner         5883
# RG Sharma         5881
# SK Raina          5536
# AB de Villiers    5181
# CH Gayle          4997
# MS Dhoni          4978
# RV Uthappa        4954
# KD Karthik        4377
# Name: batsman_run, dtype: int64

# %% [markdown]
# ###`Q-7` No of players having runs above 3000

# %%
# code here
run[run<3000].sort_values(ascending=False)
# Out:
# batter
# BB McCullum       2882
# RR Pant           2851
# PA Patel          2848
# JC Buttler        2832
# SS Iyer           2780
#                   ...
# ND Doshi             0
# RP Meredith          0
# V Pratap Singh       0
# R Sanjay Yadav       0
# Abdur Razzak         0
# Name: batsman_run, Length: 585, dtype: int64

# %% [markdown]
# ###`Q-8` No of players having runs above mean value?

# %%
# code here
(run>run.mean()).sum()
# Out:
# 128

# %% [markdown]
# Download data - https://drive.google.com/file/d/1QZuZ5bypUInfVvarHACLAi8tXXHvb8xd/view?usp=share_link
#
# file name - items.csv

# %% [markdown]
# ###`Q-9`
#     i. Read `items.csv` making `item_name` as index.
#     ii. Show no of nan values
#     ii. Item price is given in $, so convert it to rupees without currency symbol.
#     iii. Make data type of newly made series as float.
#     iv. Fill nan with mean of the series
#
#
# How csv file looks
#
# ```
# item_name	item_price
# Chips and Fresh Tomato Salsa	$2.39
# Izze	$3.39
# Nantucket Nectar	$3.39
# Chips and Tomatillo-Green Chili Salsa	$2.39
# Chicken Bowl	$16.98
#
# ```

# %%
# code here
item=pd.read_csv('/content/drive/MyDrive/Learn_DS_dataset/items.csv',index_col='item_name')
item=item.squeeze()

# %%
item[item.isna()].size
# Out:
# 50

# %%
item
# Out:
# item_name
# Chips and Fresh Tomato Salsa              191.2
# Izze                                      271.2
# Nantucket Nectar                          271.2
# Chips and Tomatillo-Green Chili Salsa     191.2
# Chicken Bowl                             1358.4
#                                           ...
# Steak Burrito                             940.0
# Steak Burrito                             940.0
# Chicken Salad Bowl                        900.0
# Chicken Salad Bowl                        700.0
# Chicken Salad Bowl                        700.0
# Name: item_price, Length: 4622, dtype: float64

# %%
item=item.apply(lambda x: x if pd.isna(x) else float(x[1:])*80)

# %%
item[item.isna()].size
# Out:
# 0

# %%
item=item.fillna(item.mean())

# %% [markdown]
# ###`Q-10`:
#     i. Find mean price
#     ii. Find 30th and 6th percentile value
#     iii. Plot Histogram on price with bin size 50
#     iv. No of items price lies between [1000 to 2000]

# %%
# code here
item.mean()
# Out:
# 597.0425196850393

# %%
item.quantile(.5)
# Out:
# 700.0

# %%
item
# Out:
# item_name
# Chips and Fresh Tomato Salsa              191.2
# Izze                                      271.2
# Nantucket Nectar                          271.2
# Chips and Tomatillo-Green Chili Salsa     191.2
# Chicken Bowl                             1358.4
#                                           ...
# Steak Burrito                             940.0
# Steak Burrito                             940.0
# Chicken Salad Bowl                        900.0
# Chicken Salad Bowl                        700.0
# Chicken Salad Bowl                        700.0
# Name: item_price, Length: 4622, dtype: float64

# %%
item
# Out:
# item_name
# Chips and Fresh Tomato Salsa              191.2
# Izze                                      271.2
# Nantucket Nectar                          271.2
# Chips and Tomatillo-Green Chili Salsa     191.2
# Chicken Bowl                             1358.4
#                                           ...
# Steak Burrito                             940.0
# Steak Burrito                             940.0
# Chicken Salad Bowl                        900.0
# Chicken Salad Bowl                        700.0
# Chicken Salad Bowl                        700.0
# Name: item_price, Length: 4622, dtype: float64

# %%
import numpy as np
# plt(np.histogram(item,bins=a))
item.hist(bins=50)
# Out:
# <Axes: >

# %%
item.between (1000, 2000).sum()
# Out:
# 116

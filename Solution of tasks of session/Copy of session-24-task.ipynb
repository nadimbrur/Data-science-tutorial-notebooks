# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder

plt.style.use('default')

# %% [markdown]
# ## **Problem 1 to 2:**
#
# **Dataset link:** https://rb.gy/gsmddu
#
# **Add a label to every axis and add a proper title for the charts (For every subplot, it is applicable). Also add proper labels if there are multiple representations.** Then, you can customize it as your wish.

# %% [markdown]
# ### **Problem-1:** Make a subplots which have 2 plots.
#
# - For the first chart, draw a scatter plot "*Monitored Cap.(MW)*" vs "*Total Cap. Under Maintenance (MW)*" of top 5 most frequent power stations. Then draw the lines which indicate the average values of these two columns. Change the colors according to the names of the Power Stations.
# - For the second chart, draw a scatter plot "*Monitored Cap. (MW)*" vs "*Actual(MU)*" of the top 5 most frequent power stations. Also draw the lines which indicates the average values of these two columns. Change the colors according to the names of the Power Stations.

# %%
import pandas as pd

# %%
# code here
df = pd.read_csv('https://rb.gy/gsmddu')

# %%
df.columns
# Out:
# Index(['Dates', 'Power Station', 'Monitored Cap.(MW)',
#        'Total Cap. Under Maintenace (MW)', 'Planned Maintanence (MW)',
#        'Forced Maintanence(MW)', 'Other Reasons (MW)',
#        'Programme or Expected(MU)', 'Actual(MU)', 'Excess(+) / Shortfall (-)',
#        'Deviation'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['Dates', 'Power Station', 'Monitored Cap.(MW)',
#        'Total Cap. Under Maintenace (MW)', 'Planned Maintanence (MW)',
#        'Forced Maintanence(MW)', 'Other Reasons (MW)',
#        'Programme or Expected(MU)', 'Actual(MU)', 'Excess(+) / Shortfall (-)',
#        'Deviation'],
#       dtype='object')

# %%
df
# Out:
#              Dates      Power Station  Monitored Cap.(MW)  \
# 0       2017-09-01              Delhi              2235.4
# 1       2017-09-01            Haryana              2720.0
# 2       2017-09-01   Himachal Pradesh              3378.0
# 3       2017-09-01  Jammu and Kashmir              1285.0
# 4       2017-09-01             Punjab              3826.3
# ...            ...                ...                 ...
# 345268  2022-04-13            Tripura               137.0
# 345269  2022-04-13            NEEPCO.              2027.0
# 345270  2022-04-13               NHPC               105.0
# 345271  2022-04-13          NTPC Ltd.               750.0
# 345272  2022-04-13               ONGC               726.6
#
#         Total Cap. Under Maintenace (MW)  Planned Maintanence (MW)  \
# 0                                 135.00                      0.00
# 1                                2470.00                      0.00
# 2                                 379.00                      0.00
# 3                                 150.00                      0.00
# 4                                2697.65                     77.65
# ...                                  ...                       ...
# 345268                             32.00                      0.00
# 345269                            963.50                    313.50
# 345270                             35.00                      0.00
# 345271                            250.00                      0.00
# 345272                              0.00                      0.00
#
#         Forced Maintanence(MW)  Other Reasons (MW)  Programme or Expected(MU)  \
# 0                        135.0                   0                         13
# 1                       2470.0                   0                         28
# 2                        231.0                   0                         40
# 3                          0.0                   0                         14
# 4                       2620.0                   0                         39
# ...                        ...                 ...                        ...
# 345268                     0.0                  32                          0
# 345269                   650.0                   0                          0
# 345270                    35.0                   0                          0
# 345271                   250.0                   0                          0
# 345272                     0.0                   0                          0
#
#         Actual(MU)  Excess(+) / Shortfall (-)  Deviation
# 0               18                       5.00        0.0
# 1                7                     -21.80        0.0
# 2               46                       5.63        0.0
# 3               23                       9.43        0.0
# 4               17                     -21.69        0.0
# ...            ...                        ...        ...
# 345268           1                       0.29        0.0
# 345269          12                      -1.59        0.0
# 345270           0                      -0.72        0.0
# 345271          11                       4.45        0.0
# 345272          13                       1.80        0.0
#
# [345273 rows x 11 columns]

# %%
group = df.groupby('Power Station')[['Power Station','Monitored Cap.(MW)','Total Cap. Under Maintenace (MW)']].agg({
    'Monitored Cap.(MW)':'mean',
    'Total Cap. Under Maintenace (MW)':'mean',
      'Power Station':'size',
    }).rename(columns={'Power Station': 'group_size'}).reset_index().sort_values(by='group_size', ascending=False).head(5)

# %%
group[['Power Station','Monitored Cap.(MW)','Total Cap. Under Maintenace (MW)']].plot(kind='line',x='Power Station')
# Out:
# <Axes: xlabel='Power Station'>

# %%
plt.plot(group['Power Station'], group['Monitored Cap.(MW)'], label='Monitored')
plt.plot(group['Power Station'], group['Total Cap. Under Maintenace (MW)'], label='Under Maintence')
plt.xlabel('Power station')
plt.ylabel('Monitored cap vs Total cap')
plt.legend()
plt.show()

# %% [markdown]
# ### **Problem-2:** Draw a 3D Scatter plot between "*Monitored Cap.(MW)*", "*Total Cap. Under Maintenace (MW)*" and "*Forced Maintanence(MW)*"

# %%
# code here

fig = plt.figure(figsize=(10,6))
ax = plt.subplot(projection='3d')
p = ax.scatter3D(df['Monitored Cap.(MW)'], df['Total Cap. Under Maintenace (MW)'], df['Forced Maintanence(MW)'])
ax.set_title('MW')
ax.set_xlabel('Monitored Camp. (MW)')
ax.set_ylabel('Total cap. Under Maintence (MW)')
ax.set_zlabel('Forced Maintence (MW)')
fig.colorbar(p)
plt.show()

# %% [markdown]
# ### **Problem-3:** Make a 3D *Surface* plot of this below mathematical equation.
#
# $$z = |x| - |y|$$

# %%
# code here
import numpy as np

x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

xx, yy = np.meshgrid(x,y)
z= np.abs(xx)- np.abs(yy)

fig = plt.figure(figsize=(12,8))
ax = plt.subplot(projection='3d')
p=ax.plot_surface(xx,yy,z)
fig.colorbar(p)

# %% [markdown]
# ### **Problem-4:** Draw the 3D *Contour plot* of this below equation:
#
# $$z = |x| - |y|$$

# %%
# code here
import numpy as np

x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

xx, yy = np.meshgrid(x,y)
z= np.abs(xx)- np.abs(yy)

fig = plt.figure(figsize=(12,8))
ax = plt.subplot()
p=ax.contour(xx,yy,z,50,cmap='viridis')
fig.colorbar(p)

# %% [markdown]
# ### **Problem-5:** Draw a second type of Countour plot of the below equation:
#
# $$z = |x| - |y|$$

# %%
# code here# code here
import numpy as np

x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

xx, yy = np.meshgrid(x,y)
z= np.abs(xx)- np.abs(yy)

fig = plt.figure(figsize=(12,8))
ax = plt.subplot()
p=ax.contourf(xx,yy,z,50,cmap='viridis')
fig.colorbar(p)

# %% [markdown]
# ## `Problem 6-7`
#
# Data Set Link - https://docs.google.com/spreadsheets/d/17tUL2yC7MGvo7txuuhLtAI-b6_C4jc0t7FLFxqRm-uI/edit?usp=share_link
#
#
# **Description of Dataset:**
#
# * Date: It gives the date of which stocks details are given.
# * Symbol: Name of stock
# * Open: It gives the opening price of stock on that date.
# * High: It gives the highest price to which the stock ascened on that day.
# * Low: It gives the highest price to which the stock plummeted on that day.
# * Close: It gives the closing price of stock on that date.
# * Volume: It gives the amount of stock traded on that date.
# * VWAP: The volume-weighted average price (VWAP) is a statistic used by traders to determine what the average price is based on both price and volume.
# * Turnover:

# %% [markdown]
# ### `Problem-6` Use Pandas plot functions
#
# * Line plot of closing value of top 5 Stocks in Year 2020.
# * Take top 5 stocks based on total turnover in Year 2020

# %%
# code here
df= pd.read_csv('/content/nifty-50 - nifty-50.csv')

# %%
df['year']= pd.to_datetime(df['Date']).dt.year

# %%
df_tmp = df[df['year']==2020]

# %%
df_tmp['Symbol'].value_counts().head(5)
# Out:
# Symbol
# WIPRO       750
# GRASIM      750
# HDFCBANK    500
# UTIBANK     500
# TISCO       500
# Name: count, dtype: int64

# %%
df_tmp=df_tmp[df_tmp['Symbol'].isin(['WIPRO','GRASIM','HDFCBANK','UTIBANK','TISCO'])]

# %%
df_tmp.pivot_table(index='Date', columns='Symbol',values='Close').plot(kind='line')
# Out:
# <Axes: xlabel='Date'>

# %%
df_tmp = df[df['year']==2020]

# %%
# Out:
# array(['ZEETELE', 'INFOSYSTCH', 'RELIANCE', 'WIPRO', 'ITC'], dtype=object)

# %%
df_tmp[df_tmp['Symbol'].isin(df_tmp.groupby('Symbol')['Turnover'].sum().sort_values(ascending=False).head(5).index.values)].pivot_table(index='Date', columns='Symbol',values='Close').plot(kind='line')
# Out:
# <Axes: xlabel='Date'>

# %%
.pivot_table(index='Date', columns='Symbol',values='Close').plot(kind='line')

# %% [markdown]
# ### `Problem-7` Scatter plot Close price vs Volume for TOP-5 Stocks in year 2021
# * Color on Symbol Column

# %%
df_tmp = df[df['year']==2021]

# %%
df_tmp=df_tmp[df_tmp['Symbol'].isin(df_tmp['Symbol'].value_counts().head(5).index.values)]

# %%
df_tmp['Symbol']=df_tmp['Symbol'].replace({
    'GRASIM':1,
    'WIPRO':2,
    'DRREDDY':3,
    'EICHERMOT':4,
    'ONGC':5

})

# %%
df_tmp.plot(kind='scatter',x='Close', y='Volume',c='Symbol', cmap='jet')
# Out:
# <Axes: xlabel='Close', ylabel='Volume'>

# %% [markdown]
# ### `Problem-8` Create a 3-D Scatter Plot using `time,x,y` on below synthetic data. and give color gradiant on `z`
# ```
# # Create a 3D dataset
# time = np.linspace(0, 10, 100)
# x = np.sin(time)
# y = np.cos(time)
# z = time
#
# # Create a DataFrame from the dataset
# data = pd.DataFrame({'time': time, 'x': x, 'y': y, 'z': z})
# ```

# %%
# code here
# Create a 3D dataset
time = np.linspace(0, 10, 100)
x = np.sin(time)
y = np.cos(time)
z = time

# Create a DataFrame from the dataset
df = pd.DataFrame({'time': time, 'x': x, 'y': y, 'z': z})
fig = plt.figure()

ax = plt.subplot(projection='3d')
ax.scatter3D(df['x'],df['y'],df['z'], marker='+', c=z )
plt.show()

# %% [markdown]
# ### `Problem 9:` Create a surface plot and the 2 types of the contour plots of the below equation.
#
# $$z = sin(\sqrt{x^2 + y^2})$$

# %%
# code here
x = np.linspace(0, 10, 100)
y = np.linspace(0, 10, 100)
xx, yy = np.meshgrid(x,y)
z= np.sin((xx**2+yy**2)**0.5)

fig = plt.figure()
ax = plt.subplot(projection='3d')
p=ax.plot_surface(xx,yy,z)
fig.colorbar(p)

# %%
# code here
x = np.linspace(0, 10, 100)
y = np.linspace(0, 10, 100)
xx, yy = np.meshgrid(x,y)
z= np.sin((xx**2+yy**2)**0.5)

fig = plt.figure()
ax = plt.subplot()
p=ax.contour(xx,yy,z)
fig.colorbar(p)

# %%
# code here
x = np.linspace(0, 10, 100)
y = np.linspace(0, 10, 100)
xx, yy = np.meshgrid(x,y)
z= np.sin((xx**2+yy**2)**0.5)

fig = plt.figure()
ax = plt.subplot()
p=ax.contourf(xx,yy,z)
fig.colorbar(p)

# %% [markdown]
# ### `Problem 10:` Create a surface plot and the 2 types of the contour plots of the below equation.
#
# $$z = tan(\log_2({x^2 + y^2})$$

# %%
# code here
# code here
x = np.linspace(0, 10, 100)
y = np.linspace(0, 10, 100)
xx, yy = np.meshgrid(x,y)
z= np.tan(np.log(xx**2+yy**2))

fig = plt.figure()
ax = plt.subplot()
p=ax.contour(xx,yy,z)
fig.colorbar(p)
# Out:
# <ipython-input-137-5f0509b321e8>:6: RuntimeWarning: divide by zero encountered in log
#   z= np.tan(np.log(xx**2+yy**2))
# <ipython-input-137-5f0509b321e8>:6: RuntimeWarning: invalid value encountered in tan
#   z= np.tan(np.log(xx**2+yy**2))
